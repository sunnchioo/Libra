# %% [markdown]
# ## single compare

# %%
## ckks level=35-17  time=85.3821ms error=0.0035704

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.collections import EventCollection
from matplotlib.lines import Line2D
from matplotlib.markers import MarkerStyle
from matplotlib import rcParams

# 全局配置优化：统一字体大小和样式
config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 10,      # 子图标题字体
    "axes.labelsize": 9,       # 轴标签字体
    "xtick.labelsize": 8,      # x轴刻度字体
    "ytick.labelsize": 8,      # y轴刻度字体
    "legend.fontsize": 7,      # 图例字体
}
rcParams.update(config)

# Fixing random state for reproducibility
np.random.seed(19680801)

# create random data
xdata = np.arange(0, 10, step=1)

# create some y data points
rlwe1 = [1 for _ in range(10)]
rlwe2 = [1.974725902 for _ in range(10)]
lwe1 = [
0.708971354,
0.554355866,
0.544594236,
0.539592487,
0.537284167,
0.537955764,
0.535793036,
1.052598045,
1.571596638,
2.605206986
]
lwe2 = [
0.708971354,
0.554355866,
0.544594236,
0.539592487,
0.537284167,
0.537955764,
0.535793036,
1.052598045,
1.571596638,
2.605206986
]

# plot the data
# fig = plt.figure(figsize=(3.5, 2.163), dpi=200)
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(7, 3.5*0.618), dpi=300)
fig.set_constrained_layout(True)

marker_style1 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style2 = dict(marker='s', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")

line_style1 = dict(linestyle='-', color='tab:blue',  label='RLWE', linewidth=1)
line_style2 = dict(linestyle='--', color='tab:red', label='LWE', linewidth=1)

ax0.plot(xdata, rlwe1, **marker_style1, **line_style1)
ax0.plot(xdata, lwe1, **marker_style2, **line_style2)
ax1.plot(xdata, rlwe2, **marker_style1, **line_style1)
ax1.plot(xdata, lwe2, **marker_style2, **line_style2)

# create the events marking the y data points
# yevents01 = EventCollection(ydata1, color='tab:blue', linelength=0.4, linewidth=0.5,
#                            orientation='vertical')
# yevents02 = EventCollection(ydata2, color='tab:orange', linelength=0.4, linewidth=0.5,
#                            orientation='vertical')

# yevents11 = EventCollection(ydata1, color='tab:blue', linelength=0.4, linewidth=0.5,
#                            orientation='vertical')
# yevents12 = EventCollection(ydata3, color='tab:orange', linelength=0.4, linewidth=0.5,
#                            orientation='vertical')

# add the events to the axis
# ax0.add_collection(yevents01)
# ax0.add_collection(yevents02)
# ax1.add_collection(yevents11)
# ax1.add_collection(yevents12)

# set the limits
ax0.set_xlim([-0.5, 9.05])
ax0.set_xticks(np.arange(0, 11, step=1))
ax0.set_xticklabels([f'$2^{{{i}}}$' for i in ax0.get_xticks()], fontfamily='Times New Roman')
ax0.set_ylim([0, 3.2])
ax0.set_title('(a) RLWE Error = 10$^{-3}$', x=0.5, y=0.91, fontweight='bold', transform=ax0.transAxes)
ax0.set_ylabel('Normalized Time')
ax0.grid(True, linestyle='--', alpha=0.5)
ax0.tick_params(axis='x', pad=1)  # x轴刻度标签靠近x轴
# ax0.tick_params(axis='y', pad=1)  # y轴刻度标签靠近y轴
ax0.legend(loc='upper left', fontsize=7)

ax1.set_xlim([-0.5, 9.5])
ax1.set_xticks(np.arange(0, 11, step=1))
ax1.set_xticklabels([f'$2^{{{i}}}$' for i in ax1.get_xticks()], fontfamily='Times New Roman')
ax1.set_ylim([0, 3.2])
ax1.set_title('(b) RLWE Error = 10$^{-4}$', x=0.5, y=0.91, fontweight='bold', transform=ax1.transAxes)
# ax1.set_xlabel('log2(batch)')
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.tick_params(axis='x', pad=1)  # x轴刻度标签靠近x轴
# ax1.tick_params(axis='y', pad=1)  # y轴刻度标签靠近y轴
ax1.legend(loc='upper left', fontsize=7)

# display the plot
# fig.suptitle(y=0.95)

plt.savefig('fig/SingleOperaterCompare.pdf', format='pdf', dpi=300, bbox_inches=None, pad_inches=0)

# plt.tight_layout()
plt.show()

width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 2.16

# %% [markdown]
# ## find min

# %%
## ckks level=35-17  error=0.0035704

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.collections import EventCollection
from matplotlib.collections import EventCollection
from matplotlib.lines import Line2D
from matplotlib.markers import MarkerStyle
from matplotlib import rcParams

config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 10,      # 子图标题字体
    "axes.labelsize": 9,       # 轴标签字体
    "xtick.labelsize": 8,      # x轴刻度字体
    "ytick.labelsize": 8,      # y轴刻度字体
    "legend.fontsize": 7,      # 图例字体
}
rcParams.update(config)

# Fixing random state for reproducibility
np.random.seed(19680801)

# create random data
xdata = np.arange(1, 16, step=1)

# create some y data points
# ydata1 = [1 for _ in range(16)]
rlwe1 = [
56.70 ,
825.99 ,
1539.83 ,
2295.51 ,
3044.84 ,
3779.97 ,
4570.69 ,
5338.61 ,
6093.81 ,
6788.11 ,
7539.98 ,
8278.85 ,
9121.61 ,
9888.93 ,
10644.71 
]
lwe1 = [
55.1784,
94.3863,
141.01,
186.967,
233.059,
279.678,
325.766,
416.68,
551.988,
774.003,
1272.49,
2144.3,
3927.75,
7522.99,
14697
]

rlwe2 = [
95.46 ,
1016.22 ,
1918.70 ,
2854.76 ,
3769.15 ,
4732.40 ,
5628.36 ,
6550.46 ,
7473.65 ,
8403.12 ,
9436.13 ,
10391.20 ,
11469.40 ,
12234.80 ,
13152.91417,
]
lwe2 = [
55.1784,
94.3863,
141.01,
186.967,
233.059,
279.678,
325.766,
416.68,
551.988,
774.003,
1272.49,
2144.3,
3927.75,
7522.99,
14697
]

# 合并两组数据，计算统一的min和max（关键：使用同一标准）
all_data = np.concatenate([lwe1])
global_min = np.min(all_data)
global_max = np.max(all_data)

# 基于统一标准的归一化函数
def unified_normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# 对两组数据分别进行统一标准归一化
rlwe1 = unified_normalize(rlwe1, global_min, global_max)
lwe1 = unified_normalize(lwe1, global_min, global_max)

rlwe2 = unified_normalize(rlwe2, global_min, global_max)
lwe2 = unified_normalize(lwe2, global_min, global_max)

# plot the data
# fig = plt.figure(figsize=(3.5, 2.163), dpi=200)
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(7, 3.5*0.618), dpi=300)
fig.set_constrained_layout(True)

marker_style1 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="none")
marker_style2 = dict(marker='s', markersize=5, markerfacecolor="tab:red", markeredgecolor="none")

line_style1 = dict(linestyle='-', color='tab:blue',  label='RLWE', linewidth=1)
line_style2 = dict(linestyle=':', color='tab:red', label='LWE', linewidth=1)

# ax = fig.add_subplot(1, 1, 1)
ax0.plot(xdata, rlwe1, **marker_style1, **line_style1)
ax0.plot(xdata, lwe1, **marker_style2, **line_style2)
ax1.plot(xdata, rlwe2, **marker_style1, **line_style1)
ax1.plot(xdata, lwe2, **marker_style2, **line_style2)

# create the events marking the y data points
# yevents01 = EventCollection(ydata1, color='tab:blue', linelength=2.4, linewidth=0.5,
#                            orientation='vertical')
# yevents02 = EventCollection(ydata2, color='tab:orange', linelength=2.4, linewidth=0.5,
#                            orientation='vertical')

# yevents11 = EventCollection(ydata1, color='tab:blue', linelength=0.5, linewidth=0.5,
#                            orientation='vertical')
# yevents12 = EventCollection(ydata2, color='tab:orange', linelength=0.5, linewidth=0.5,
#                            orientation='vertical')

# add the events to the axis
# ax0.add_collection(yevents01)
# ax0.add_collection(yevents02)
# ax1.add_collection(yevents11)
# ax1.add_collection(yevents12)

# set the limits
ax0.set_xlim([0.5, 15.5])
ax0.set_xticks(np.arange(1, 16, step=2))
ax0.set_xticklabels([f'$2^{{{i}}}$' for i in ax0.get_xticks()], fontfamily='Times New Roman')
ax0.set_ylim([-0.05, 1.05])
ax0.set_title('(a) RLWE Error = 10$^{-3}$', x=0.5, y=0.91, transform=ax0.transAxes)
ax0.set_ylabel('Normalized Time')
ax0.tick_params(axis='x', pad=1)  # x轴刻度标签靠近x轴
ax0.grid(True, linestyle='--', alpha=0.5)
ax0.legend(loc='upper left', fontsize=7)

ax1.set_xlim([0.5, 15.5])
ax1.set_xticks(np.arange(1, 16, step=2))
ax1.set_xticklabels([f'$2^{{{i}}}$' for i in ax1.get_xticks()], fontfamily='Times New Roman')
ax1.set_ylim([-0.05, 1.05])
ax1.set_title('(b) RLWE Error = 10$^{-3}$', x=0.5, y=0.91, transform=ax1.transAxes)
ax1.tick_params(axis='x', pad=1)  # x轴刻度标签靠近x轴
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.legend(loc='upper left', fontsize=7)

# display the plot
# fig.suptitle(y=0.95)

plt.savefig('fig/FindMin.pdf', format='pdf', dpi=300, bbox_inches=None, pad_inches=0)

# plt.tight_layout()
plt.show()

width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 2.16

# %% [markdown]
# ## merge

# %%
## ckks level=35-17  error=0.0035704

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.collections import EventCollection
from matplotlib.collections import EventCollection
from matplotlib.lines import Line2D
from matplotlib.markers import MarkerStyle
from matplotlib import rcParams

config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 10,      # 子图标题字体
    "axes.labelsize": 9,       # 轴标签字体
    "xtick.labelsize": 8,      # x轴刻度字体
    "ytick.labelsize": 8,      # y轴刻度字体
    "legend.fontsize": 7,      # 图例字体
}
rcParams.update(config)

# Fixing random state for reproducibility
np.random.seed(19680801)

# create random data
xdata0 = np.arange(0, 10, step=1)
xdata1 = np.arange(1, 16, step=1)

# left
rlwe00 = [42.5851 for _ in range(10)]
lwe00 = [
30.191616,
23.6073,
23.1916,
22.9786,
22.8803,
22.9089,
22.8168,
44.824993,
66.9266,
110.943
]
rlwe01 = [84.0939 for _ in range(10)]
lwe01 = [
30.191616,
23.6073,
23.1916,
22.9786,
22.8803,
22.9089,
22.8168,
44.824993,
66.9266,
110.943
]

# right
rlwe10 = [
56.70,
754.15,
1441.76,
2150.02,
2852.63,
3553.93,
4259.41,
4925.05,
5630.14,
6329.23,
6980.29,
7783.43,
8371.61,
9054.94,
9746.67 
]
lwe10 = [
55.1784,
94.3863,
141.01,
186.967,
233.059,
279.678,
325.766,
416.68,
551.988,
774.003,
1272.49,
2144.3,
3927.75,
7522.99,
14697
]

rlwe11 = [
95.46 ,
1016.22 ,
1918.70 ,
2854.76 ,
3769.15 ,
4732.40 ,
5628.36 ,
6550.46 ,
7473.65 ,
8403.12 ,
9436.13 ,
10391.20 ,
11469.40 ,
12234.80 ,
13152.91417,
]
lwe11 = [
55.1784,
94.3863,
141.01,
186.967,
233.059,
279.678,
325.766,
416.68,
551.988,
774.003,
1272.49,
2144.3,
3927.75,
7522.99,
14697
]

# 基于统一标准的归一化函数
def unified_normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# 合并两组数据，计算统一的min和max（关键：使用同一标准）
all_data0 = np.concatenate([lwe00])
global0_min = np.min(all_data0)
global0_max = np.max(all_data0)


# 对两组数据分别进行统一标准归一化
rlwe00 = unified_normalize(rlwe00, global0_min, global0_max)
lwe00 = unified_normalize(lwe00, global0_min, global0_max)
rlwe01 = unified_normalize(rlwe01, global0_min, global0_max)

all_data1 = np.concatenate([lwe10])
global1_min = np.min(all_data1)
global1_max = np.max(all_data1)

rlwe10 = unified_normalize(rlwe10, global1_min, global1_max)
lwe10 = unified_normalize(lwe10, global1_min, global1_max)
rlwe11 = unified_normalize(rlwe11, global1_min, global1_max)

# plot the data
# fig = plt.figure(figsize=(3.5, 2.163), dpi=200)
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=False, figsize=(7, 3.5*0.618), dpi=300)
fig.set_constrained_layout(True)

marker_style0 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style1 = dict(marker='s', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style2 = dict(marker='^', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")

line_style0 = dict(linestyle='-', color='tab:blue',  label='RLWE', linewidth=1)
line_style1 = dict(linestyle=':', color='tab:blue',  label='RLWE', linewidth=1)
line_style2 = dict(linestyle=':', color='tab:red', label='LWE', linewidth=1)

# ax = fig.add_subplot(1, 1, 1)
ax0.plot(xdata0, rlwe00, **marker_style0, **line_style0)
ax0.plot(xdata0, rlwe01, **marker_style1, **line_style1)
ax0.plot(xdata0, lwe00, **marker_style2, **line_style2)

ax1.plot(xdata1, rlwe10, **marker_style0, **line_style0)
ax1.plot(xdata1, rlwe11, **marker_style1, **line_style1)
ax1.plot(xdata1, lwe10, **marker_style2, **line_style2)

# create the events marking the y data points
# yevents01 = EventCollection(ydata1, color='tab:blue', linelength=2.4, linewidth=0.5,
#                            orientation='vertical')
# yevents02 = EventCollection(ydata2, color='tab:orange', linelength=2.4, linewidth=0.5,
#                            orientation='vertical')

# yevents11 = EventCollection(ydata1, color='tab:blue', linelength=0.5, linewidth=0.5,
#                            orientation='vertical')
# yevents12 = EventCollection(ydata2, color='tab:orange', linelength=0.5, linewidth=0.5,
#                            orientation='vertical')

# add the events to the axis
# ax0.add_collection(yevents01)
# ax0.add_collection(yevents02)
# ax1.add_collection(yevents11)
# ax1.add_collection(yevents12)

# set the limits
ax0.set_xlim([-0.5, 9.5])
ax0.set_xticks(np.arange(0, 10, step=1))
ax0.set_xticklabels([f'$2^{{{i}}}$' for i in ax0.get_xticks()], fontfamily='Times New Roman')
ax0.set_ylim([-0.05, 1.05])
ax0.set_title('(a) Compare', x=0.5, y=0.91, fontweight='bold', transform=ax0.transAxes)
ax0.set_ylabel('Normalized Time')
ax0.grid(True, linestyle='--', alpha=0.5)
ax0.tick_params(axis='x', pad=1)  # x轴刻度标签靠近x轴
# ax0.tick_params(axis='y', pad=1)  # y轴刻度标签靠近y轴
ax0.legend(loc='upper left', fontsize=7)

ax1.set_xlim([0.5, 15.5])
ax1.set_xticks(np.arange(1, 16, step=2))
ax1.set_xticklabels([f'$2^{{{i}}}$' for i in ax1.get_xticks()], fontfamily='Times New Roman')
ax1.set_ylim([-0.05, 1.05])
ax1.set_title('(b) FindMin', x=0.5, y=0.91, fontweight='bold', transform=ax1.transAxes)
ax1.tick_params(axis='x', pad=1)  # x轴刻度标签靠近x轴
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.legend(loc='upper left', fontsize=7)

# display the plot
# fig.suptitle(y=0.95)

plt.savefig('fig/TradeoffPoint.pdf', format='pdf', dpi=300, bbox_inches=None, pad_inches=0)

# plt.tight_layout()
plt.show()

width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 2.16

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# 全局配置（保持不变）
config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 10,
    "axes.labelsize": 9,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "legend.fontsize": 7,
}
rcParams.update(config)

# 数据部分（保持不变）
np.random.seed(19680801)
xdata0 = np.arange(0, 10, step=1)
xdata1 = np.arange(1, 16, step=1)

# left数据
rlwe00 = [42.5851 for _ in range(10)]
lwe00 = [30.191616,23.6073,23.1916,22.9786,22.8803,22.9089,22.8168,44.824993,66.9266,110.943]
rlwe01 = [84.0939 for _ in range(10)]
lwe01 = [30.191616,23.6073,23.1916,22.9786,22.8803,22.9089,22.8168,44.824993,66.9266,110.943]

# right数据
rlwe10 = [56.70,754.15,1441.76,2150.02,2852.63,3553.93,4259.41,4925.05,5630.14,6329.23,6980.29,7783.43,8371.61,9054.94,9746.67]
lwe10 = [55.1784,94.3863,141.01,186.967,233.059,279.678,325.766,416.68,551.988,774.003,1272.49,2144.3,3927.75,7522.99,14697]
rlwe11 = [95.46,1016.22,1918.70,2854.76,3769.15,4732.40,5628.36,6550.46,7473.65,8403.12,9436.13,10391.20,11469.40,12234.80,13152.91417]
lwe11 = [55.1784,94.3863,141.01,186.967,233.059,279.678,325.766,416.68,551.988,774.003,1272.49,2144.3,3927.75,7522.99,14697]

# 归一化函数（保持不变）
def unified_normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# 归一化处理（保持不变）
all_data0 = np.concatenate([lwe00])
global0_min, global0_max = np.min(all_data0), np.max(all_data0)
rlwe00_norm = unified_normalize(rlwe00, global0_min, global0_max)
rlwe01_norm = unified_normalize(rlwe01, global0_min, global0_max)
lwe00_norm = unified_normalize(lwe00, global0_min, global0_max)

all_data1 = np.concatenate([lwe10])
global1_min, global1_max = np.min(all_data1), np.max(all_data1)
rlwe10_norm = unified_normalize(rlwe10, global1_min, global1_max)
rlwe11_norm = unified_normalize(rlwe11, global1_min, global1_max)
lwe10_norm = unified_normalize(lwe10, global1_min, global1_max)

# 绘图（核心添加注释部分）
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=False, figsize=(7, 3.5*0.618), dpi=300)
fig.set_constrained_layout(True)

# 样式参数（保持不变）
marker_style0 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style1 = dict(marker='s', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style2 = dict(marker='^', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")
line_style0 = dict(linestyle='-', color='tab:blue', label='RLWE', linewidth=1)
line_style1 = dict(linestyle=':', color='tab:blue', label='RLWE', linewidth=1)
line_style2 = dict(linestyle=':', color='tab:red', label='LWE', linewidth=1)

# 绘制曲线（保持不变）
ax0.plot(xdata0, rlwe00_norm, **marker_style0,** line_style0)
ax0.plot(xdata0, rlwe01_norm, **marker_style1,** line_style1)
ax0.plot(xdata0, lwe00_norm, **marker_style2,** line_style2)
ax1.plot(xdata1, rlwe10_norm, **marker_style0,** line_style0)
ax1.plot(xdata1, rlwe11_norm, **marker_style1,** line_style1)
ax1.plot(xdata1, lwe10_norm, **marker_style2,** line_style2)

# 设置坐标轴（保持不变）
ax0.set_xlim([-0.5, 9.5])
ax0.set_xticks(np.arange(0, 10, step=1))
ax0.set_xticklabels([f'$2^{{{i}}}$' for i in ax0.get_xticks()])
ax0.set_ylim([-0.05, 1.05])
ax0.set_title('(a) Compare', x=0.5, y=0.91, fontweight='bold', transform=ax0.transAxes)
ax0.set_ylabel('Normalized Time')
ax0.grid(True, linestyle='--', alpha=0.5)
ax0.tick_params(axis='x', pad=1)
ax0.legend(loc='upper left', fontsize=7)

ax1.set_xlim([0.5, 15.5])
ax1.set_xticks(np.arange(1, 16, step=2))
ax1.set_xticklabels([f'$2^{{{i}}}$' for i in ax1.get_xticks()])
ax1.set_ylim([-0.05, 1.05])
ax1.set_title('(b) FindMin', x=0.5, y=0.91, fontweight='bold', transform=ax1.transAxes)
ax1.tick_params(axis='x', pad=1)
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.legend(loc='upper left', fontsize=7)

# -------------------------- 添加注释 --------------------------
# 第一幅图(ax0)：添加max error=10^-3和max error=10^-4
# 关联蓝色实线(RLWE)和点线(RLWE)，放在右上角，用箭头指向对应曲线
ax0.annotate(
    r'$\max\ \text{error}=10^{-3}$',  # 注释文本（Latex格式）
    xy=(7, rlwe00_norm[7]),  # 箭头指向的位置（取曲线上的点）
    xytext=(5.5, 0.35),  # 文本位置（左下角区域）
    arrowprops=dict(arrowstyle='->', color='black', linewidth=0.8),  # 箭头样式
    color='black',  # 文本颜色与曲线一致
    fontsize=6
    # bbox=dict(facecolor='white', edgecolor='none', alpha=0.8)  # 白色背景避免遮挡
)

ax0.annotate(
    r'$\max\ \text{error}=10^{-4}$',
    xy=(8.4, rlwe01_norm[8]),  # 指向点线RLWE曲线
    xytext=(6.8, 0.83),  # 文本位置在下方，避免重叠
    arrowprops=dict(arrowstyle='->', color='black', linewidth=0.8),
    color='black',
    fontsize=6,
    # bbox=dict(facecolor='white', edgecolor='none', alpha=0.7)
)

# 第二幅图(ax1)：添加max error=10^-1和max error=10^-2
# 关联蓝色实线和点线RLWE曲线，位置选择右侧区域
ax1.annotate(
    r'$\max\ \text{error}=10^{-1}$',
    xy=(14.2, rlwe10_norm[13]),  # 指向实线RLWE曲线
    xytext=(12.3, 0.45),  # 右侧区域文本位置
    arrowprops=dict(arrowstyle='->', color='black', linewidth=0.8),
    color='black',
    fontsize=6
    # bbox=dict(facecolor='white', edgecolor='none', alpha=0.7)
)

ax1.annotate(
    r'$\max\ \text{error}=10^{-2}$',
    xy=(14.8, rlwe11_norm[14]-0.01),  # 指向点线RLWE曲线
    xytext=(11.5, 0.95),  # 下方位置避免重叠
    arrowprops=dict(arrowstyle='->', color='black', linewidth=0.8),
    color='black',
    fontsize=6
    # bbox=dict(facecolor='white', edgecolor='none', alpha=0.7)
)
# --------------------------------------------------------------

# 保存与显示（保持不变）
plt.savefig('fig/TradeoffPoint.pdf', format='pdf', dpi=300, bbox_inches=None, pad_inches=0)
plt.show()

width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 2.16

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# 全局配置
config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 10,
    "axes.labelsize": 9,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "legend.fontsize": 7,
}
rcParams.update(config)

# 数据部分
np.random.seed(19680801)
xdata0 = np.arange(0, 10, step=1)
xdata1 = np.arange(1, 16, step=1)

# left数据
rlwe00 = [42.5851 for _ in range(10)]
lwe00 = [30.191616,23.6073,23.1916,22.9786,22.8803,22.9089,22.8168,44.824993,66.9266,110.943]
rlwe01 = [84.0939 for _ in range(10)]

# right数据
rlwe10 = [56.70,754.15,1441.76,2150.02,2852.63,3553.93,4259.41,4925.05,5630.14,6329.23,6980.29,7783.43,8371.61,9054.94,9746.67]
lwe10 = [55.1784,94.3863,141.01,186.967,233.059,279.678,325.766,416.68,551.988,774.003,1272.49,2144.3,3927.75,7522.99,14697]
rlwe11 = [95.46,1016.22,1918.70,2854.76,3769.15,4732.40,5628.36,6550.46,7473.65,8403.12,9436.13,10391.20,11469.40,12234.80,13152.91417]

# 归一化函数
def unified_normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# 归一化处理
all_data0 = np.concatenate([lwe00])
global0_min, global0_max = np.min(all_data0), np.max(all_data0)
rlwe00_norm = unified_normalize(rlwe00, global0_min, global0_max)
rlwe01_norm = unified_normalize(rlwe01, global0_min, global0_max)
lwe00_norm = unified_normalize(lwe00, global0_min, global0_max)

all_data1 = np.concatenate([lwe10])
global1_min, global1_max = np.min(all_data1), np.max(all_data1)
rlwe10_norm = unified_normalize(rlwe10, global1_min, global1_max)
rlwe11_norm = unified_normalize(rlwe11, global1_min, global1_max)
lwe10_norm = unified_normalize(lwe10, global1_min, global1_max)

# 绘图
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=False, figsize=(7, 3.5*0.65), dpi=300)
fig.set_constrained_layout(True)

# 样式参数
marker_style0 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style1 = dict(marker='s', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style2 = dict(marker='^', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")
line_style0 = dict(linestyle='-', color='tab:blue', label='RLWE', linewidth=1)
line_style1 = dict(linestyle=':', color='tab:blue', label='RLWE', linewidth=1)
line_style2 = dict(linestyle=':', color='tab:red', label='LWE', linewidth=1)

# 绘制曲线
ax0.plot(xdata0, rlwe00_norm, **marker_style0,** line_style0)
ax0.plot(xdata0, rlwe01_norm, **marker_style1,** line_style1)
ax0.plot(xdata0, lwe00_norm, **marker_style2,** line_style2)
ax1.plot(xdata1, rlwe10_norm, **marker_style0,** line_style0)
ax1.plot(xdata1, rlwe11_norm, **marker_style1,** line_style1)
ax1.plot(xdata1, lwe10_norm, **marker_style2,** line_style2)

# 设置坐标轴
ax0.set_xlim([-0.5, 9.5])
ax0.set_xticks(np.arange(0, 10, step=1))
ax0.set_xticklabels([f'$2^{{{i}}}$' for i in ax0.get_xticks()])
ax0.set_ylim([-0.05, 1.05])
ax0.set_title('(a) Compare', x=0.5, y=0.91, fontweight='bold', transform=ax0.transAxes)
ax0.set_ylabel('Normalized Latency')
ax0.set_xlabel('Data Pairs', labelpad=0.2)
ax0.grid(True, linestyle='--', alpha=0.5)
ax0.tick_params(axis='x', pad=1)
ax0.legend(loc='upper left', fontsize=7)

ax1.set_xlim([0.5, 15.5])
ax1.set_xticks(np.arange(1, 16, step=2))
ax1.set_xticklabels([f'$2^{{{i}}}$' for i in ax1.get_xticks()])
ax1.set_ylim([-0.05, 1.05])
ax1.set_title('(b) FindMin', x=0.5, y=0.91, fontweight='bold', transform=ax1.transAxes)
ax1.set_xlabel('Data Size', labelpad=0.2)  # 添加ax1的横坐标标签
ax1.tick_params(axis='x', pad=1)
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.legend(loc='upper left', fontsize=7)

# -------------------------- 美化后的注释 --------------------------
# 第一幅图(ax0)注释
ax0.annotate(
    r'max error=10$^{-3}$',
    xy=(6.9, rlwe00_norm[7]),  # 保持指向位置不变
    xytext=(5, 0.35),      # 保持文本位置不变
    arrowprops=dict(
        arrowstyle='->', 
        color='black', 
        linewidth=1,
        shrinkA=0,  # 箭头与文本的距离
        shrinkB=2   # 箭头与目标点的距离
    ),
    color='black',
    fontsize=8,
    fontweight='bold',  # 加粗文本增强可读性
    # bbox=dict(          # 添加半透明白色背景框
    #     facecolor='white', 
    #     edgecolor='lightgray', 
    #     alpha=0.8,
    #     boxstyle='round,pad=0.3'  # 圆角边框
    # )
)

ax0.annotate(
    r'max error=10$^{-4}$',
    xy=(8.4, rlwe01_norm[8]),  # 保持指向位置不变
    xytext=(6.5, 0.83),        # 保持文本位置不变
    arrowprops=dict(
        arrowstyle='->', 
        color='black', 
        linewidth=1,
        shrinkA=0,
        shrinkB=2
    ),
    color='black',
    fontsize=8,
    fontweight='bold',
    # bbox=dict(
    #     facecolor='white', 
    #     edgecolor='lightgray', 
    #     alpha=0.8,
    #     boxstyle='round,pad=0.3'
    # )
)

# 第二幅图(ax1)注释
ax1.annotate(
    r'max error=10$^{-1}$',
    xy=(14.25, rlwe10_norm[13]+0.01),  # 保持指向位置不变
    xytext=(11.5, 0.45),         # 保持文本位置不变
    arrowprops=dict(
        arrowstyle='->', 
        color='black', 
        linewidth=1,
        shrinkA=0,
        shrinkB=2
    ),
    color='black',
    fontsize=8,
    fontweight='bold',
    # bbox=dict(
    #     facecolor='white', 
    #     edgecolor='lightgray', 
    #     alpha=0.8,
    #     boxstyle='round,pad=0.3'
    # )
)

ax1.annotate(
    r'max error=10$^{-2}$',
    xy=(14.8, rlwe11_norm[14]-0.01),  # 保持指向位置不变
    xytext=(11, 0.95),              # 保持文本位置不变
    arrowprops=dict(
        arrowstyle='->', 
        color='black', 
        linewidth=1,
        shrinkA=0,
        shrinkB=2
    ),
    color='black',
    fontsize=8,
    fontweight='bold',
    # bbox=dict(
    #     facecolor='white', 
    #     edgecolor='lightgray', 
    #     alpha=0.8,
    #     boxstyle='round,pad=0.3'
    # )
)
# --------------------------------------------------------------

# 保存与显示
plt.savefig('fig/TradeoffPoint.pdf', format='pdf', dpi=400, bbox_inches=None, pad_inches=0)
plt.show()

width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 2.27

# %% [markdown]
# ## 分开画

# %%
## ckks level=35-17  error=0.0035704

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.collections import EventCollection
from matplotlib.collections import EventCollection
from matplotlib.lines import Line2D
from matplotlib.markers import MarkerStyle
from matplotlib import rcParams

config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 10,      # 子图标题字体
    "axes.labelsize": 9,       # 轴标签字体
    "xtick.labelsize": 8,      # x轴刻度字体
    "ytick.labelsize": 8,      # y轴刻度字体
    "legend.fontsize": 7,      # 图例字体
}
rcParams.update(config)

# Fixing random state for reproducibility
np.random.seed(19680801)

# create random data
xdata0 = np.arange(0, 10, step=1)
xdata1 = np.arange(0, 10, step=1)

# comp
rlwe0 = [59.3091 for _ in range(10)]
lwe0 = [
37.6658,
36.6213,
35.8646,
35.6598,
35.4688,
35.6448,
34.9317,
66.0804,
105.727,
172.791
]

rlwe1 = [89.6502 for _ in range(10)]
lwe1 = [
43.522,
42.4049,
41.9891,
41.8232,
41.7536,
41.5048,
41.6123,
77.0445,
121.935,
200.815
]

# 归一化函数
def unified_normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# 归一化处理
all_data0 = np.concatenate([lwe0[0:-1], rlwe0, rlwe1, lwe1[0:-1]])
# all_data0 = np.concatenate([lwe0, rlwe0])
global0_min, global0_max = np.min(all_data0), np.max(all_data0)
rlwe0_norm = unified_normalize(rlwe0, global0_min, global0_max)
lwe0_norm = unified_normalize(lwe0, global0_min, global0_max)

all_data1 = np.concatenate([lwe0[0:-1], rlwe0, rlwe1, lwe1[0:-1]])
# all_data1 = np.concatenate([rlwe1, lwe1])
global1_min, global1_max = np.min(all_data1), np.max(all_data1)
rlwe1_norm = unified_normalize(rlwe1, global1_min, global1_max)
lwe1_norm = unified_normalize(lwe1, global1_min, global1_max)

# plot the data
# fig = plt.figure(figsize=(3.5, 2.163), dpi=200)
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True, figsize=(7, 3.5*0.618), dpi=300)
fig.set_constrained_layout(True)

marker_style0 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style1 = dict(marker='s', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")
# marker_style2 = dict(marker='^', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")

line_style0 = dict(linestyle='-', color='tab:blue',  label='Poly', linewidth=1)
line_style1 = dict(linestyle=':', color='tab:red',  label='LUT', linewidth=1)
# line_style2 = dict(linestyle=':', color='tab:red', label='LWE', linewidth=1)

# ax = fig.add_subplot(1, 1, 1)
ax0.plot(xdata0, rlwe0_norm, **marker_style0, **line_style0)
ax0.plot(xdata0, lwe0_norm, **marker_style1, **line_style1)
# ax0.plot(xdata0, lwe00, **marker_style2, **line_style2)

ax1.plot(xdata1, rlwe1_norm, **marker_style0, **line_style0)
ax1.plot(xdata1, lwe1_norm, **marker_style1, **line_style1)
# ax1.plot(xdata1, lwe10, **marker_style2, **line_style2)

# create the events marking the y data points
# yevents01 = EventCollection(ydata1, color='tab:blue', linelength=2.4, linewidth=0.5,
#                            orientation='vertical')
# yevents02 = EventCollection(ydata2, color='tab:orange', linelength=2.4, linewidth=0.5,
#                            orientation='vertical')

# yevents11 = EventCollection(ydata1, color='tab:blue', linelength=0.5, linewidth=0.5,
#                            orientation='vertical')
# yevents12 = EventCollection(ydata2, color='tab:orange', linelength=0.5, linewidth=0.5,
#                            orientation='vertical')

# add the events to the axis
# ax0.add_collection(yevents01)
# ax0.add_collection(yevents02)
# ax1.add_collection(yevents11)
# ax1.add_collection(yevents12)

# set the limits
ax0.set_xlim([-0.5, 8.5])
ax0.set_xticks(np.arange(0, 9, step=1))
ax0.set_xticklabels([f'$2^{{{int(i)}}}$' for i in np.arange(0, 9, step=1)])  # 修正：使用整数索引
ax0.set_ylim([-0.05, 1.1])
ax0.set_title('(a) Compare MAE=10$^{-2}$', x=0.5, y=0.91, fontweight='bold', transform=ax0.transAxes)  # 移除不必要的transform
ax0.set_ylabel('Normalized Latency')
# ax0.set_xlabel('Data Pairs', labelpad=0.2)
ax0.grid(True, linestyle='--', alpha=0.5)
ax0.tick_params(axis='x', pad=1)
ax0.legend(loc='upper left', fontsize=7)

ax1.set_xlim([-0.5, 8.5])
ax1.set_xticks(np.arange(0, 9, step=1))
ax1.set_xticklabels([f'$2^{{{int(i)}}}$' for i in np.arange(0, 9, step=1)])  # 修正：使用整数索引
# ax1.set_ylim([-0.05, 1.05])
ax1.set_title('(b) Compare MAE=10$^{-4}$', x=0.5, y=0.91, fontweight='bold', transform=ax1.transAxes)  # 移除不必要的transform 
# ax1.set_ylabel('Normalized Latency')
# ax1.set_xlabel('Data Pairs', labelpad=0.2)
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.tick_params(axis='x', pad=1)
ax1.legend(loc='upper left', fontsize=7)

pos0 = ax0.get_position()
pos1 = ax1.get_position()
joint_left = pos0.x0
joint_right = pos1.x1
joint_center_x = (joint_left + joint_right) / 2
fig.text(joint_center_x+0.016, 0, 'Number of Data Pairs', ha='center', va='center', fontsize=9)
# display the plot
# fig.suptitle(y=0.95)

plt.savefig('fig/SingleCompare.pdf', format='pdf', dpi=400, bbox_inches='tight', pad_inches=0)

# plt.tight_layout() 
plt.show()

width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 2.16

# %% [markdown]
# ## FindMin

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.collections import EventCollection
from matplotlib.collections import EventCollection
from matplotlib.lines import Line2D
from matplotlib.markers import MarkerStyle
from matplotlib import rcParams

config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 10,      # 子图标题字体
    "axes.labelsize": 9,       # 轴标签字体
    "xtick.labelsize": 8,      # x轴刻度字体
    "ytick.labelsize": 8,      # y轴刻度字体
    "legend.fontsize": 7,      # 图例字体
}
rcParams.update(config)

# Fixing random state for reproducibility
np.random.seed(19680801)

# create random data
xdata0 = np.arange(1, 16, step=1)
xdata1 = np.arange(1, 16, step=1)

# findmin
rlwe0 = [
56.70 ,
754.15 ,
1441.76 ,
2150.02 ,
2852.63 ,
3553.93 ,
4259.41 ,
4925.05 ,
5630.14 ,
6329.23 ,
6980.29 ,
7783.43 ,
8371.61 ,
9054.94 ,
9746.67 
]
lwe0 = [
81.09 ,
146.46 ,
218.24 ,
289.33 ,
360.49 ,
432.09 ,
503.61 ,
647.42 ,
855.74 ,
1201.15 ,
1941.76 ,
3310.67 ,
6079.79 ,
11690.60 ,
22873.80 
]

rlwe1 = [
95.46 ,
1016.22, 
1918.70 ,
2854.76 ,
3769.15 ,
4732.40 ,
5628.36 ,
6550.46 ,
7473.65 ,
8403.12 ,
9436.13 ,
10391.20 ,
11469.40 ,
12234.80 ,
13152.91417
]
lwe1 = [
93.20 ,
169.99 ,
255.04 ,
337.97 ,
420.47 ,
505.30 ,
589.14 ,
749.51 ,
1053.12 ,
1436.80 ,
2279.21 ,
3941.08 ,
7302.67 ,
13894.20 ,
27277.70 
]

# 归一化函数
def unified_normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# 归一化处理
all_data0 = np.concatenate([lwe0, rlwe0, rlwe1, lwe1])
# all_data0 = np.concatenate([lwe0, rlwe0])
global0_min, global0_max = np.min(all_data0), np.max(all_data0)
rlwe0_norm = unified_normalize(rlwe0, global0_min, global0_max)
lwe0_norm = unified_normalize(lwe0, global0_min, global0_max)

all_data1 = np.concatenate([lwe0, rlwe0, rlwe1, lwe1])
# all_data1 = np.concatenate([rlwe1, lwe1])
global1_min, global1_max = np.min(all_data1), np.max(all_data1)
rlwe1_norm = unified_normalize(rlwe1, global1_min, global1_max)
lwe1_norm = unified_normalize(lwe1, global1_min, global1_max)

# plot the data
# fig = plt.figure(figsize=(3.5, 2.163), dpi=200)
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True, figsize=(7, 3.5*0.618), dpi=300)
fig.set_constrained_layout(True)

marker_style0 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style1 = dict(marker='s', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")
# marker_style2 = dict(marker='^', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")

line_style0 = dict(linestyle='-', color='tab:blue',  label='Poly', linewidth=1)
line_style1 = dict(linestyle=':', color='tab:red',  label='LUT', linewidth=1)
# line_style2 = dict(linestyle=':', color='tab:red', label='LWE', linewidth=1)

ax0.plot(xdata0, rlwe0_norm, **marker_style0, **line_style0)
ax0.plot(xdata0, lwe0_norm, **marker_style1, **line_style1)

ax1.plot(xdata1, rlwe1_norm, **marker_style0, **line_style0)
ax1.plot(xdata1, lwe1_norm, **marker_style1, **line_style1)

# set the limits
ax0.set_xlim([0.5, 15.5])
ax0.set_xticks(np.arange(1, 16, step=2))
ax0.set_xticklabels([f'$2^{{{i}}}$' for i in ax1.get_xticks()])
ax0.set_ylim([-0.05, 1.05])
ax0.set_title('(a) FindMin MAE=10$^{-1}$', x=0.5, y=0.91, fontweight='bold', transform=ax0.transAxes)
# ax1.set_xlabel('Data Size', labelpad=0.2)  # 添加ax1的横坐标标签
ax0.tick_params(axis='x', pad=1)
ax0.grid(True, linestyle='--', alpha=0.5)
ax0.legend(loc='upper left', fontsize=7)

ax1.set_xlim([0.5, 15.5])
ax1.set_xticks(np.arange(1, 16, step=2))
ax1.set_xticklabels([f'$2^{{{i}}}$' for i in ax1.get_xticks()])
ax1.set_ylim([-0.05, 1.05])
ax1.set_title('(b) FindMin MAE=10$^{-2}$', x=0.5, y=0.91, fontweight='bold', transform=ax1.transAxes)
# ax1.set_xlabel('Data Size', labelpad=0.2)  # 添加ax1的横坐标标签
ax1.tick_params(axis='x', pad=1)
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.legend(loc='upper left', fontsize=7)

pos0 = ax0.get_position()
pos1 = ax1.get_position()
joint_left = pos0.x0
joint_right = pos1.x1
joint_center_x = (joint_left + joint_right) / 2
fig.text(joint_center_x+0.016, 0, 'Data Size', ha='center', va='center', fontsize=9)
# display the plot
# fig.suptitle(y=0.95)

plt.savefig('fig/FindMin.pdf', format='pdf', dpi=400, bbox_inches=None, pad_inches=0)

# plt.tight_layout() 
plt.show()

width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 2.16

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.collections import EventCollection
from matplotlib.collections import EventCollection
from matplotlib.lines import Line2D
from matplotlib.markers import MarkerStyle
from matplotlib import rcParams

config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 10,      # 子图标题字体
    "axes.labelsize": 9,       # 轴标签字体
    "xtick.labelsize": 8,      # x轴刻度字体
    "ytick.labelsize": 8,      # y轴刻度字体
    "legend.fontsize": 7,      # 图例字体
}
rcParams.update(config)

# Fixing random state for reproducibility
np.random.seed(19680801)

# create random data
xdata0 = np.arange(1, 16, step=1)
xdata1 = np.arange(1, 16, step=1)

# findmin
rlwe0 = [
56.70 ,
754.15 ,
1441.76 ,
2150.02 ,
2852.63 ,
3553.93 ,
4259.41 ,
4925.05 ,
5630.14 ,
6329.23 ,
6980.29 ,
7783.43 ,
8371.61 ,
9054.94 ,
9746.67 
]
lwe0 = [
81.09 ,
146.46 ,
218.24 ,
289.33 ,
360.49 ,
432.09 ,
503.61 ,
647.42 ,
855.74 ,
1201.15 ,
1941.76 ,
3310.67 ,
6079.79 ,
11690.60 ,
22873.80 
]

rlwe1 = [
115.83 ,
1151.71 ,
2155.57 ,
3201.69 ,
4240.42 ,
5279.86 ,
6342.50 ,
7435.14 ,
8497.78 ,
9660.42 ,
10761.06 ,
11823.70 ,
13016.34 ,
14198.98 ,
15261.62
]
lwe1 = [
93.20 ,
169.99 ,
255.04 ,
337.97 ,
420.47 ,
505.30 ,
589.14 ,
749.51 ,
1053.12 ,
1436.80 ,
2279.21 ,
3941.08 ,
7302.67 ,
13894.20 ,
27277.70 
]

# 归一化函数
def unified_normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# 归一化处理
all_data0 = np.concatenate([lwe0, rlwe0, rlwe1, lwe1])
# all_data0 = np.concatenate([lwe0, rlwe0])
global0_min, global0_max = np.min(all_data0), np.max(all_data0)
rlwe0_norm = unified_normalize(rlwe0, global0_min, global0_max)
lwe0_norm = unified_normalize(lwe0, global0_min, global0_max)

all_data1 = np.concatenate([lwe0, rlwe0, rlwe1, lwe1])
# all_data1 = np.concatenate([rlwe1, lwe1])
global1_min, global1_max = np.min(all_data1), np.max(all_data1)
rlwe1_norm = unified_normalize(rlwe1, global1_min, global1_max)
lwe1_norm = unified_normalize(lwe1, global1_min, global1_max)

# plot the data
# fig = plt.figure(figsize=(3.5, 2.163), dpi=200)
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True, figsize=(7, 3.5*0.618), dpi=300)
fig.set_constrained_layout(True)

marker_style0 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style1 = dict(marker='s', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")
# marker_style2 = dict(marker='^', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")

line_style0 = dict(linestyle='-', color='tab:blue',  label='Poly', linewidth=1)
line_style1 = dict(linestyle=':', color='tab:red',  label='LUT', linewidth=1)
# line_style2 = dict(linestyle=':', color='tab:red', label='LWE', linewidth=1)

ax0.plot(xdata0, rlwe0_norm, **marker_style0, **line_style0)
ax0.plot(xdata0, lwe0_norm, **marker_style1, **line_style1)

ax1.plot(xdata1, rlwe1_norm, **marker_style0, **line_style0)
ax1.plot(xdata1, lwe1_norm, **marker_style1, **line_style1)

# set the limits
ax0.set_xlim([0.5, 15.5])
ax0.set_xticks(np.arange(1, 16, step=2))
ax0.set_xticklabels([f'$2^{{{i}}}$' for i in ax1.get_xticks()])
ax0.set_ylim([-0.05, 1.05])
ax0.set_title('(a) FindMin MAE=10$^{-1}$', x=0.5, y=0.91, fontweight='bold', transform=ax0.transAxes)
ax0.set_ylabel('Normalized Latency')
# ax1.set_xlabel('Data Size', labelpad=0.2)  # 添加ax1的横坐标标签
ax0.tick_params(axis='x', pad=1)
ax0.grid(True, linestyle='--', alpha=0.5)
ax0.legend(loc='upper left', fontsize=7)

ax1.set_xlim([0.5, 15.5])
ax1.set_xticks(np.arange(1, 16, step=2))
ax1.set_xticklabels([f'$2^{{{i}}}$' for i in ax1.get_xticks()])
ax1.set_ylim([-0.05, 1.05])
ax1.set_title('(b) FindMin MAE=10$^{-3}$', x=0.5, y=0.91, fontweight='bold', transform=ax1.transAxes)
# ax1.set_xlabel('Data Size', labelpad=0.2)  # 添加ax1的横坐标标签
ax1.tick_params(axis='x', pad=1)
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.legend(loc='upper left', fontsize=7)

pos0 = ax0.get_position()
pos1 = ax1.get_position()
joint_left = pos0.x0
joint_right = pos1.x1
joint_center_x = (joint_left + joint_right) / 2
fig.text(joint_center_x+0.0025, 0, 'Data Size', ha='center', va='center', fontsize=9)
# display the plot
# fig.suptitle(y=0.95)

plt.savefig('fig/FindMin.pdf', format='pdf', dpi=400, bbox_inches='tight', pad_inches=0)

# plt.tight_layout() 
plt.show()

width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 2.16

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# 配置字体和样式
config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 10,      # 子图标题字体
    "axes.labelsize": 9,       # 轴标签字体
    "xtick.labelsize": 8,      # x轴刻度字体
    "ytick.labelsize": 8,      # y轴刻度字体
    "legend.fontsize": 7,      # 图例字体
}
rcParams.update(config)

# 归一化函数
def unified_normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# 设置样式
marker_style0 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
marker_style1 = dict(marker='s', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")
line_style0 = dict(linestyle='-', color='tab:blue',  label='Poly', linewidth=1)
line_style1 = dict(linestyle=':', color='tab:red',  label='LUT', linewidth=1)

# 创建上下结构的图形
fig, axes = plt.subplots(nrows=2, ncols=2, sharex='col', sharey='row', 
                         figsize=(7, 7*0.618), dpi=300)
fig.set_constrained_layout(True)

# -------------------- 第一个图的数据和绘制 (上半部分) --------------------
# 数据
xdata0 = np.arange(0, 10, step=1)
xdata1 = np.arange(0, 10, step=1)

# comp数据
rlwe0 = [59.3091 for _ in range(10)]
lwe0 = [37.6658, 36.6213, 35.8646, 35.6598, 35.4688, 35.6448, 34.9317, 66.0804, 105.727, 172.791]

rlwe1 = [89.6502 for _ in range(10)]
lwe1 = [43.522, 42.4049, 41.9891, 41.8232, 41.7536, 41.5048, 41.6123, 77.0445, 121.935, 200.815]

# 归一化处理
all_data0 = np.concatenate([lwe0[0:-1], rlwe0, rlwe1, lwe1[0:-1]])
global0_min, global0_max = np.min(all_data0), np.max(all_data0)
rlwe0_norm = unified_normalize(rlwe0, global0_min, global0_max)
lwe0_norm = unified_normalize(lwe0, global0_min, global0_max)

all_data1 = np.concatenate([lwe0[0:-1], rlwe0, rlwe1, lwe1[0:-1]])
global1_min, global1_max = np.min(all_data1), np.max(all_data1)
rlwe1_norm = unified_normalize(rlwe1, global1_min, global1_max)
lwe1_norm = unified_normalize(lwe1, global1_min, global1_max)

# 绘制上半部分子图
ax0, ax1 = axes[0, 0], axes[0, 1]

ax0.plot(xdata0, rlwe0_norm, **marker_style0,** line_style0)
ax0.plot(xdata0, lwe0_norm, **marker_style1,** line_style1)
ax0.set_xlim([-0.5, 8.5])
ax0.set_xticks(np.arange(0, 9, step=1))
ax0.set_xticklabels([f'$2^{{{int(i)}}}$' for i in np.arange(0, 9, step=1)])
ax0.set_ylim([-0.05, 1.1])
ax0.set_title('(a) Compare MAE=10$^{-2}$', x=0.5, y=0.91, fontweight='bold', transform=ax0.transAxes)
ax0.set_ylabel('Normalized Latency')
ax0.grid(True, linestyle='--', alpha=0.5)
ax0.tick_params(axis='x', pad=1)
ax0.legend(loc='upper left', fontsize=7)

ax1.plot(xdata1, rlwe1_norm, **marker_style0,** line_style0)
ax1.plot(xdata1, lwe1_norm, **marker_style1,** line_style1)
ax1.set_xlim([-0.5, 8.5])
ax1.set_xticks(np.arange(0, 9, step=1))
ax1.set_xticklabels([f'$2^{{{int(i)}}}$' for i in np.arange(0, 9, step=1)])
ax1.set_title('(b) Compare MAE=10$^{-4}$', x=0.5, y=0.91, fontweight='bold', transform=ax1.transAxes)
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.tick_params(axis='x', pad=1)
ax1.legend(loc='upper left', fontsize=7)

# -------------------- 第二个图的数据和绘制 (下半部分) --------------------
# 数据
xdata2 = np.arange(1, 16, step=1)
xdata3 = np.arange(1, 16, step=1)

# findmin数据
rlwe2 = [56.70, 754.15, 1441.76, 2150.02, 2852.63, 3553.93, 4259.41, 4925.05, 5630.14, 6329.23, 6980.29, 7783.43, 8371.61, 9054.94, 9746.67]
lwe2 = [81.09, 146.46, 218.24, 289.33, 360.49, 432.09, 503.61, 647.42, 855.74, 1201.15, 1941.76, 3310.67, 6079.79, 11690.60, 22873.80]

rlwe3 = [115.83, 1151.71, 2155.57, 3201.69, 4240.42, 5279.86, 6342.50, 7435.14, 8497.78, 9660.42, 10761.06, 11823.70, 13016.34, 14198.98, 15261.62]
lwe3 = [93.20, 169.99, 255.04, 337.97, 420.47, 505.30, 589.14, 749.51, 1053.12, 1436.80, 2279.21, 3941.08, 7302.67, 13894.20, 27277.70]

# 归一化处理
all_data2 = np.concatenate([lwe2, rlwe2, rlwe3, lwe3])
global2_min, global2_max = np.min(all_data2), np.max(all_data2)
rlwe2_norm = unified_normalize(rlwe2, global2_min, global2_max)
lwe2_norm = unified_normalize(lwe2, global2_min, global2_max)

all_data3 = np.concatenate([lwe2, rlwe2, rlwe3, lwe3])
global3_min, global3_max = np.min(all_data3), np.max(all_data3)
rlwe3_norm = unified_normalize(rlwe3, global3_min, global3_max)
lwe3_norm = unified_normalize(lwe3, global3_min, global3_max)

# 绘制下半部分子图
ax2, ax3 = axes[1, 0], axes[1, 1]

ax2.plot(xdata2, rlwe2_norm, **marker_style0,** line_style0)
ax2.plot(xdata2, lwe2_norm, **marker_style1,** line_style1)
ax2.set_xlim([0.5, 15.5])
ax2.set_xticks(np.arange(1, 16, step=2))
ax2.set_xticklabels([f'$2^{{{i}}}$' for i in ax2.get_xticks()])
ax2.set_ylim([-0.05, 1.05])
ax2.set_title('(c) FindMin MAE=10$^{-1}$', x=0.5, y=0.91, fontweight='bold', transform=ax2.transAxes)
ax2.set_ylabel('Normalized Latency')
ax2.tick_params(axis='x', pad=1)
ax2.grid(True, linestyle='--', alpha=0.5)
ax2.legend(loc='upper left', fontsize=7)

ax3.plot(xdata3, rlwe3_norm, **marker_style0,** line_style0)
ax3.plot(xdata3, lwe3_norm, **marker_style1,** line_style1)
ax3.set_xlim([0.5, 15.5])
ax3.set_xticks(np.arange(1, 16, step=2))
ax3.set_xticklabels([f'$2^{{{i}}}$' for i in ax3.get_xticks()])
ax3.set_ylim([-0.05, 1.05])
ax3.set_title('(d) FindMin MAE=10$^{-3}$', x=0.5, y=0.91, fontweight='bold', transform=ax3.transAxes)
ax3.tick_params(axis='x', pad=1)
ax3.grid(True, linestyle='--', alpha=0.5)
ax3.legend(loc='upper left', fontsize=7)

# 添加全局x轴标签
pos2 = ax2.get_position()
pos3 = ax3.get_position()
joint_left = pos2.x0
joint_right = pos3.x1
joint_center_x = (joint_left + joint_right) / 2
fig.text(joint_center_x, 0.01, 'Data Size', ha='center', va='center', fontsize=9)

# 保存和显示
# plt.savefig('fig/Combined_Plot.pdf', format='pdf', dpi=400, bbox_inches='tight', pad_inches=0.05)
plt.show()

width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 4.33

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# 设置全局字体和样式
config = {
    "font.family": "Times New Roman",
    "mathtext.fontset": "custom",
    "mathtext.rm": "Times New Roman",
    "axes.unicode_minus": False,
    "axes.titlesize": 12,
    "axes.labelsize": 12,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "legend.fontsize": 10,
    "grid.alpha": 0.3
}
rcParams.update(config)

# 创建2×2的子图画布
fig, axs = plt.subplots(2, 2, figsize=(7, 7*0.618+0.45), dpi=300, sharey=True)
# fig.subplots_adjust(hspace=0.25)  # 调整子图间距
fig.set_constrained_layout(True)
fig.set_constrained_layout_pads(h_pad=0.1)

np.random.seed(19680801)  # 固定随机种子

# ======================= 第一个图：比较图 ======================= 
xdata0 = np.arange(0, 10, step=1)
rlwe0 = [59.3091 for _ in range(10)]
lwe0 = [37.6658, 36.6213, 35.8646, 35.6598, 35.4688, 35.6448, 34.9317, 66.0804, 105.727, 172.791]
rlwe1 = [89.6502 for _ in range(10)]
lwe1 = [43.522, 42.4049, 41.9891, 41.8232, 41.7536, 41.5048, 41.6123, 77.0445, 121.935, 200.815]

# 归一化函数
def unified_normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# 归一化处理（比较图）
all_data_comp = np.concatenate([lwe0[0:-1], rlwe0, rlwe1, lwe1[0:-1]])
global_min_comp, global_max_comp = np.min(all_data_comp), np.max(all_data_comp)
rlwe0_norm = unified_normalize(rlwe0, global_min_comp, global_max_comp)
lwe0_norm = unified_normalize(lwe0, global_min_comp, global_max_comp)
rlwe1_norm = unified_normalize(rlwe1, global_min_comp, global_max_comp)
lwe1_norm = unified_normalize(lwe1, global_min_comp, global_max_comp)

# 绘制比较图
# marker_style0 = dict(marker='o', markersize=5, markerfacecolor="tab:blue", markeredgecolor="white")
# marker_style1 = dict(marker='s', markersize=5, markerfacecolor="tab:red", markeredgecolor="white")
marker_style0 = dict(marker='o', markersize=6, markerfacecolor="white", markeredgecolor="tab:blue")
marker_style1 = dict(marker='s', markersize=6, markerfacecolor="white", markeredgecolor="tab:red")
line_style0 = dict(linestyle='-', color='tab:blue', label='SIMD-FHE', linewidth=1)
line_style1 = dict(linestyle='--', color='tab:red', label='SISD-FHE', linewidth=1)

# 左上子图：MAE=10^{-2}
axs[0, 0].plot(xdata0, rlwe0_norm, **marker_style0, **line_style0)
axs[0, 0].plot(xdata0, lwe0_norm, **marker_style1, **line_style1)
axs[0, 0].set_xlim([-0.5, 8.5])
axs[0, 0].set_xticks(np.arange(0, 9, step=1))
axs[0, 0].set_xticklabels([f'$2^{{{int(i)}}}$' for i in np.arange(0, 9, step=1)])
axs[0, 0].set_ylim([-0.05, 1.1])
# axs[0, 0].set_title('(a) Compare MAE=10$^{-2}$', fontweight='bold', pad=10)
axs[0, 0].set_title('(a) Compare MAE=10$^{-2}$', x=0.5, y=1.03, fontweight='bold', transform=axs[0, 0].transAxes)
axs[0, 0].set_ylabel('Normalized Latency')
axs[0, 0].grid(True, linestyle='--', alpha=0.3)
axs[0, 0].legend(loc='upper left', fontsize=10)

# 右上子图：MAE=10^{-4}
axs[0, 1].plot(xdata0, rlwe1_norm, **marker_style0, **line_style0)
axs[0, 1].plot(xdata0, lwe1_norm, **marker_style1, **line_style1)
axs[0, 1].set_xlim([-0.5, 8.5])
axs[0, 1].set_xticks(np.arange(0, 9, step=1))
axs[0, 1].set_xticklabels([f'$2^{{{int(i)}}}$' for i in np.arange(0, 9, step=1)])
# axs[0, 1].set_title('(b) Compare MAE=10$^{-4}$', fontweight='bold', pad=10)
axs[0, 1].set_title('(b) Compare MAE=10$^{-4}$', x=0.5, y=1.03, fontweight='bold', transform=axs[0, 1].transAxes)
axs[0, 1].grid(True, linestyle='--', alpha=0.3)
axs[0, 1].legend(loc='upper left', fontsize=10)

# ======================= 第二个图：FindMin ======================= 
xdata1 = np.arange(1, 16, step=1)
rlwe0 = [56.70, 754.15, 1441.76, 2150.02, 2852.63, 3553.93, 4259.41, 4925.05, 5630.14, 6329.23, 6980.29, 7783.43, 8371.61, 9054.94, 9746.67]
lwe0 = [81.09, 146.46, 218.24, 289.33, 360.49, 432.09, 503.61, 647.42, 855.74, 1201.15, 1941.76, 3310.67, 6079.79, 11690.60, 22873.80]
rlwe1 = [115.83, 1151.71, 2155.57, 3201.69, 4240.42, 5279.86, 6342.50, 7435.14, 8497.78, 9660.42, 10761.06, 11823.70, 13016.34, 14198.98, 15261.62]
lwe1 = [93.20, 169.99, 255.04, 337.97, 420.47, 505.30, 589.14, 749.51, 1053.12, 1436.80, 2279.21, 3941.08, 7302.67, 13894.20, 27277.70]

# 归一化处理（FindMin）
all_data_findmin = np.concatenate([lwe0, rlwe0, rlwe1, lwe1])
global_min_findmin, global_max_findmin = np.min(all_data_findmin), np.max(all_data_findmin)
rlwe0_norm = unified_normalize(rlwe0, global_min_findmin, global_max_findmin)
lwe0_norm = unified_normalize(lwe0, global_min_findmin, global_max_findmin)
rlwe1_norm = unified_normalize(rlwe1, global_min_findmin, global_max_findmin)
lwe1_norm = unified_normalize(lwe1, global_min_findmin, global_max_findmin)

# 绘制FindMin
# 左下子图：MAE=10^{-1}
axs[1, 0].plot(xdata1, rlwe0_norm, **marker_style0, **line_style0)
axs[1, 0].plot(xdata1, lwe0_norm, **marker_style1, **line_style1)
axs[1, 0].set_xlim([0.5, 15.5])
axs[1, 0].set_xticks(np.arange(1, 16, step=2))
axs[1, 0].set_xticklabels([f'$2^{{{i}}}$' for i in range(1, 16, 2)])
axs[1, 0].set_ylim([-0.05, 1.05])
# axs[1, 0].set_title('(c) FindMin MAE=10$^{-1}$', fontweight='bold', pad=10)
axs[1, 0].set_title('(c) FindMin MAE=10$^{-1}$', x=0.5, y=1.03, fontweight='bold', transform=axs[1, 0].transAxes)
axs[1, 0].set_ylabel('Normalized Latency')
# axs[1, 0].set_xlabel('Data Size', labelpad=5)
axs[1, 0].grid(True, linestyle='--', alpha=0.3)
axs[1, 0].legend(loc='upper left', fontsize=10)

# 右下子图：MAE=10^{-3}
axs[1, 1].plot(xdata1, rlwe1_norm, **marker_style0, **line_style0)
axs[1, 1].plot(xdata1, lwe1_norm, **marker_style1, **line_style1)
axs[1, 1].set_xlim([0.5, 15.5])
axs[1, 1].set_xticks(np.arange(1, 16, step=2))
axs[1, 1].set_xticklabels([f'$2^{{{i}}}$' for i in range(1, 16, 2)])
# axs[1, 1].set_title('(d) FindMin MAE=10$^{-3}$', fontweight='bold', pad=10)
axs[1, 1].set_title('(d) FindMin MAE=10$^{-3}$', x=0.5, y=1.03, fontweight='bold', transform=axs[1, 1].transAxes)
# axs[1, 1].set_xlabel('Data Size', labelpad=5)
axs[1, 1].grid(True, linestyle='--', alpha=0.3)
axs[1, 1].legend(loc='upper left', fontsize=10)

# 添加共享标签
fig.text(0.531, 0.505, 'Number of Data Pairs', ha='center', va='center', fontsize=15)
fig.text(0.531, 0.005, 'Data Size', ha='center', va='center', fontsize=15)

# 保存和显示
plt.savefig('fig/TradeoffPoint.pdf', format='pdf', dpi=400, bbox_inches='tight', pad_inches=0)
plt.show()

# 打印图片尺寸
width, height = fig.get_size_inches()
print(f"图片大小（英寸）: 宽 = {width:.2f}, 高 = {height:.2f}")
# Out:
# 图片大小（英寸）: 宽 = 7.00, 高 = 4.78
